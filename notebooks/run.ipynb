# %%
from dbx_container.data.scraper import RuntimeScraper

# %%
scraper = RuntimeScraper()
scraper.display_runtimes()
# Out:
# SSL certificate verification is disabled
# Fetching runtime version links
# Processing runtime release 16.2
# Processing runtime release 16.1
# Processing runtime release 16.0
# Processing runtime release 15.4 LTS
# Processing runtime release 14.3 LTS
# Processing runtime release 13.3 LTS
# Processing runtime release 12.2 LTS
# Processing runtime release 11.3 LTS
# Processing runtime release 10.4 LTS
# Processing runtime release 9.1 LTS
# Successfully fetched 20 runtime versions
#                                Databricks Runtime Versions (20 total)
# ┏━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━┳━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━┳━━━━━━━┳━━━━━━━━━━━━┓
# ┃ Version       ┃ Release Date ┃ Python  ┃ Java                      ┃ Scala   ┃ R     ┃ Delta Lake ┃
# ┡━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━╇━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━╇━━━━━━━╇━━━━━━━━━━━━┩
# │ 9.1 LTS       │ 2021-09-23   │ 3.8.10  │ Zulu 8.56.0.21-CA-linux64 │ 2.12.10 │ 4.1.1 │ 1.0.0      │
# ...
